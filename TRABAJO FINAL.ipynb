# %%
import pandas as pd  #importando las libreiras necesarias
import numpy as np
data1 = pd.read_csv('data/poblacion.csv')
data2 = pd.read_csv('data/mortandadInfantil.csv')

# %%
x = (data1.append(data2)) #matriz de datos combinada 
x
# Out:
#          country    year  population  Country Name Country Code  \
# 0    Afghanistan  1952.0   8425333.0           NaN          NaN
# 1    Afghanistan  1957.0   9240934.0           NaN          NaN
# 2    Afghanistan  1962.0  10267083.0           NaN          NaN
# 3    Afghanistan  1967.0  11537966.0           NaN          NaN
# 4    Afghanistan  1972.0  13079460.0           NaN          NaN
# ..           ...     ...         ...           ...          ...
# 259          NaN     NaN         NaN        Kosovo          XKX
# 260          NaN     NaN         NaN   Yemen, Rep.          YEM
# 261          NaN     NaN         NaN  South Africa          ZAF
# 262          NaN     NaN         NaN        Zambia          ZMB
# 263          NaN     NaN         NaN      Zimbabwe          ZWE
#
#               Indicator Name Indicator Code     1960     1961     1962  ...  \
# 0                        NaN            NaN      NaN      NaN      NaN  ...
# ...

# %%
merged = pd.merge(data1, data2, how='outer',
                  left_on='country', right_on='Country Name')
merged = merged.drop('Indicator Code', 1) # drop duplicate info
merged.head()
# Out:
#        country    year  population Country Name Country Code  \
# 0  Afghanistan  1952.0   8425333.0  Afghanistan          AFG
# 1  Afghanistan  1957.0   9240934.0  Afghanistan          AFG
# 2  Afghanistan  1962.0  10267083.0  Afghanistan          AFG
# 3  Afghanistan  1967.0  11537966.0  Afghanistan          AFG
# 4  Afghanistan  1972.0  13079460.0  Afghanistan          AFG
#
#             Indicator Name  1960  1961  1962      1963  ...     2012     2013  \
# 0  Number of infant deaths   NaN   NaN   NaN  106871.0  ...  69517.0  67069.0
# 1  Number of infant deaths   NaN   NaN   NaN  106871.0  ...  69517.0  67069.0
# 2  Number of infant deaths   NaN   NaN   NaN  106871.0  ...  69517.0  67069.0
# 3  Number of infant deaths   NaN   NaN   NaN  106871.0  ...  69517.0  67069.0
# 4  Number of infant deaths   NaN   NaN   NaN  106871.0  ...  69517.0  67069.0
#
#       2014     2015     2016     2017     2018     2019  2020  Unnamed: 65
# ...

# %%
merged[merged['population'].isnull()].head()
# Out:
#      country  year  population          Country Name Country Code  \
# 1704     NaN   NaN         NaN                 Aruba          ABW
# 1705     NaN   NaN         NaN               Andorra          AND
# 1706     NaN   NaN         NaN            Arab World          ARB
# 1707     NaN   NaN         NaN  United Arab Emirates          ARE
# 1708     NaN   NaN         NaN               Armenia          ARM
#
#                Indicator Name  1960   1961   1962   1963  ...      2012  \
# 1704  Number of infant deaths   NaN    NaN    NaN    NaN  ...       NaN
# 1705  Number of infant deaths   NaN    NaN    NaN    NaN  ...       3.0
# 1706  Number of infant deaths   NaN    NaN    NaN    NaN  ...  302300.0
# 1707  Number of infant deaths   NaN  606.0  611.0  617.0  ...     682.0
# 1708  Number of infant deaths   NaN    NaN    NaN    NaN  ...     660.0
#
#           2013      2014      2015      2016      2017      2018      2019  \
# ...

# %%
merged.loc[merged['country'].isnull(), 'Country Name'].unique()
# Out:
# array(['Aruba', 'Andorra', 'Arab World', 'United Arab Emirates',
#        'Armenia', 'American Samoa', 'Antigua and Barbuda', 'Azerbaijan',
#        'Bahamas, The', 'Belarus', 'Belize', 'Bermuda', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Central Europe and the Baltics',
#        'Channel Islands', 'Cabo Verde', 'Caribbean small states',
#        'Curacao', 'Cayman Islands', 'Cyprus', 'Dominica',
#        'East Asia & Pacific (excluding high income)',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia', 'Egypt, Arab Rep.', 'Euro area',
#        'Estonia', 'European Union',
#        'Fragile and conflict affected situations', 'Fiji',
#        'Faroe Islands', 'Micronesia, Fed. Sts.', 'Georgia', 'Gibraltar',
#        'Gambia, The', 'Grenada', 'Greenland', 'Guam', 'Guyana',
#        'High income', 'Hong Kong SAR, China',
# ...

# %%
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'

# %%
merged.isnull().any()
# Out:
# country         True
# year            True
# population      True
# Country Name    True
# Country Code    True
#                 ...
# 2017            True
# 2018            True
# 2019            True
# 2020            True
# Unnamed: 65     True
# Length: 68, dtype: bool
